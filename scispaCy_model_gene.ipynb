# %%
import scispacy
import spacy
import en_core_sci_sm
from spacy import displacy
from scispacy.abbreviation import AbbreviationDetector
from scispacy.umls_linking import UmlsEntityLinker

# %%
# pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.2.4/en_core_sci_lg-0.2.4.tar.gz

# %%
nlp = spacy.load("/home/isha/en_ner_craft_md-0.2.4/en_ner_craft_md/en_ner_craft_md-0.2.4")
text = """Background: Since APOE alleles represent the most impactful genetic risk factors for Alzheimer's disease (AD), their differential mechanism(s) of action are under intense scrutiny. APOE4 is robustly associated with increased AD risk compared to the neutral APOE3 and protective APOE2. APOE alleles have also been associated with differential inflammation and gastrointestinal recovery after insult in human and murine studies, leading us to hypothesize that APOE alleles impact the gut microbiome.
Methods: To assess this hypothesis, we compared 16S ribosomal RNA gene amplicon-based microbiome profiles in a cohort of mice that were homozygous for APOE2, APOE3, or APOE4, and included both males and females as well as carriers and non-carriers of five familial AD (5xFAD) mutations. Fecal samples were analyzed from mice at 4 and 6 months of age. APOE genotype, as well as sex and 5xFAD status, was then tested for influence on alpha diversity (Shannon H index) and beta diversity (principal coordinate analyses and PERMANOVA). A Random Forest analysis was used to identify features that predicted APOE, sex and 5xFAD status.
Results: The richness and evenness (alpha diversity) of the fecal microbiome was not robustly associated with APOE genotype, 5xFAD status or sex. In contrast, microbial community composition (beta-diversity) was consistently and strongly associated with APOE genotype. The association between beta-diversity and sex or 5xFAD status was less consistent and more modest. Comparison of the differences underlying APOE effects showed that the relative abundance of multiple bacterial taxa was significantly different as a function of APOE genotype.
Conclusions: The structure of the gut microbiome was strongly and significantly associated with APOE alleles in this murine model. Further evaluation of these findings in humans, as well as studies evaluating the impact of the APOE-associated microbiota on AD-relevant phenotypes in murine models, will be necessary to determine if alterations in the gut microbiome represent a novel mechanism whereby APOE genotype impacts AD."""
doc = nlp(text)

# %%
print(list(doc.sents))
# Out:
# [Background: Since APOE alleles represent the most impactful genetic risk factors for Alzheimer's disease (AD), their differential mechanism(s) of action are under intense scrutiny., APOE4 is robustly associated with increased AD risk compared to the neutral APOE3 and protective APOE2., APOE alleles have also been associated with differential inflammation and gastrointestinal recovery after insult in human and murine studies, leading us to hypothesize that APOE alleles impact the gut microbiome.
# , Methods: To assess this hypothesis, we compared 16S ribosomal RNA gene amplicon-based microbiome profiles in a cohort of mice that were homozygous for APOE2, APOE3, or APOE4, and included both males and females as well as carriers and non-carriers of five familial AD (5xFAD) mutations., Fecal samples were analyzed from mice at 4 and 6 months of age., APOE genotype, as well as sex and 5xFAD status, was then tested for influence on alpha diversity (Shannon H index) and beta diversity (principal coordinate analyses and PERMANOVA)., A Random Forest analysis was used to identify features that predicted APOE, sex and 5xFAD status.
# , Results: The richness and evenness (alpha diversity) of the fecal microbiome was not robustly associated with APOE genotype, 5xFAD status or sex., In contrast, microbial community composition (beta-diversity) was consistently and strongly associated with APOE genotype., The association between beta-diversity and sex or 5xFAD status was less consistent and more modest., Comparison of the differences underlying APOE effects showed that the relative abundance of multiple bacterial taxa was significantly different as a function of APOE genotype.
# , Conclusions: The structure of the gut microbiome was strongly and significantly associated with APOE alleles in this murine model., Further evaluation of these findings in humans, as well as studies evaluating the impact of the APOE-associated microbiota on AD-relevant phenotypes in murine models, will be necessary to determine if alterations in the gut microbiome represent a novel mechanism whereby APOE genotype impacts AD.]

# %%
print(doc.ents)
# Out:
# (alleles, genetic, APOE4, APOE3, APOE2, alleles, human, murine, alleles, 16S ribosomal RNA gene, mice, APOE2, APOE3, APOE4, mutations, mice, genotype, predicted, APOE genotype, APOE genotype, APOE, bacterial taxa, APOE genotype, APOE alleles, murine, humans, murine, APOE genotype)

# %%
from spacy import displacy
displacy.render(next(doc.sents), style='dep', jupyter= True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="bb4901b6b4124b67a687b08767028ffa-0" class="displacy" width="4425" height="837.0" direction="ltr" style="max-width: none; height: 837.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Background:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Since</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">APOE</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">alleles</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">represent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">impactful</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">genetic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">risk</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">factors</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Alzheimer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">disease (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">AD),</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">their</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">differential</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">mechanism(s)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">action</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">under</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">intense</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">scrutiny.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bb4901b6b4124b67a687b08767028ffa-0-0" stroke-width="2px" d="M245,702.0 C245,439.5 725.0,439.5 725.0,702.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bb4901b6b4124b67a687b08767028ffa-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,704.0 L237,692.0 253,692.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bb4901b6b4124b67a687b08767028ffa-0-1" stroke-width="2px" d="M420,702.0 C420,614.5 540.0,614.5 540.0,702.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bb4901b6b4124b67a687b08767028ffa-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,704.0 L412,692.0 428,692.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bb4901b6b4124b67a687b08767028ffa-0-2" stroke-width="2px" d="M595,702.0 C595,614.5 715.0,614.5 715.0,702.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <te

# %%
# # creating a pipeline for detecting abbreviations
# abbreviation_pipe= AbbreviationDetector(nlp)
# nlp.add_pipe(abbreviation_pipe)
# print('Abbreviation', '\t', 'Definition')
# for abrv in doc._.abbreviations:
#     print(f"{abrv} \t ({abrv.start}, {abrv.end}) {abrv._.long_form}")

# %%
[(ent.text, ent.label_) for ent in doc.ents]
# Out:
# [('alleles', 'SO'),
#  ('genetic', 'SO'),
#  ('APOE4', 'GGP'),
#  ('APOE3', 'GGP'),
#  ('APOE2', 'GGP'),
#  ('alleles', 'SO'),
#  ('human', 'TAXON'),
#  ('murine', 'TAXON'),
#  ('alleles', 'SO'),
#  ('16S ribosomal RNA gene', 'SO'),
#  ('mice', 'TAXON'),
#  ('APOE2', 'GGP'),
#  ('APOE3', 'GGP'),
#  ('APOE4', 'GGP'),
#  ('mutations', 'SO'),
#  ('mice', 'TAXON'),
#  ('genotype', 'SO'),
#  ('predicted', 'SO'),
#  ('APOE genotype', 'GGP'),
#  ('APOE genotype', 'GGP'),
#  ('APOE', 'GGP'),
#  ('bacterial taxa', 'TAXON'),
#  ('APOE genotype', 'GGP'),
#  ('APOE alleles', 'GGP'),
#  ('murine', 'TAXON'),
#  ('humans', 'TAXON'),
#  ('murine', 'TAXON'),
#  ('APOE genotype', 'GGP')]

# %%
displacy.serve(doc, style= 'ent')
# Out:
# /home/isha/anaconda3/lib/python3.7/runpy.py:193: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   "__main__", mod_spec)
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">Background: Since APOE
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     alleles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SO</span>
# </mark>
#  represent the most impactful
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     genetic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SO</span>
# </mark>
#  risk factors for Alzheimer's disease (AD), their differential mechanism(s) of action are under intense scrutiny.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     APOE4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GGP</span>
# </mark>
#  is robustly associated with increased AD risk compared to the neutral
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     APOE3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GGP</span>
# </mark>
#  and protective
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     APOE2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GGP</span>
# </mark>
# . APOE
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     alleles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SO</span>
# </mark>
#  have also been associated with differential inflammation and gastrointestinal recovery after insult in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     human
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TAXON</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     murine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TAXON</span>
# </mark>
#  studies, leading us to hypothesize that APOE
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     alleles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SO</span>
# </mark>
#  impact the gut microbiome.</br>Methods: To assess this hypothesis, we compared
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     16S ribosomal RNA gene
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SO</span>
# </mark>
#  amplicon-based microbiome profiles in a cohort of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TAXON</span>
# </mark>
#  that were homozygous for
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     APOE2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GGP</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     APOE3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GGP</span>
# </mark>
# , or
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     APOE4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GGP</span>
# </mark>
# , and included both males and females as well as carriers and non-carriers of five familial AD (5xFAD)
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mutations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SO</span>
# </mark>
# . Fecal samples were analyzed from
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TAXON</span>
# </mark>
#  at 4 and 6 months of age. APOE
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     genotype
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SO</span>
# </mark>
# , as well as sex and 5xFAD status, was then tested for influence on alpha diversity (Shannon H index) and beta diversity (principal coordinate analyses and PERMANOVA). A Random Forest analysis was used to identify features that
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     predicted
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SO</span>
# </mark>
#  APOE, sex and 5xFAD status.</br>Results: The richness and evenness (alpha diversity) of the fecal microbiome was not robustly associated with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     APOE genotype
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GGP</span>
# </mark>
# , 5xFAD status or sex. In contrast, microbial community composition (beta-diversity) was consistently and strongly associated with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     APOE genotype
#     <span sty
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
